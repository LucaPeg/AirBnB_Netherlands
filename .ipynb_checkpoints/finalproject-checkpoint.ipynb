# %%
import pandas as pd

# %%
listings_ams = pd.read_csv("listings_ams.csv")
listings_rott = pd.read_csv("listings_rott.csv")
listings_hague = pd.read_csv("listings_hague.csv")
clean_hague = pd.read_csv("clean_hague.csv")

# %%
hague_colnames = [name for name in clean_hague.columns]
# Out:
#                        id
# 0                   73155
# 1                   77592
# 2                  101526
# 3                  283124
# 4                  539905
# ...                   ...
# 1086  1046356809934888376
# 1087  1047826074810654710
# 1088  1049198993122698758
# 1089  1050119352431416976
# 1090  1050172891953117352
#
# [1091 rows x 1 columns]

# %%
listings_rott = listings_rott[[hague_colnames]]
listings_rott.shape
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 listings_rott = listings_rott[[hague_colnames]]
#       2 listings_rott.shape
#
# File ~\anaconda3\envs\ml\lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\envs\ml\lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
# ...

# %%
print(f"Dim AMS: {listings_ams.shape}\nDim Rott:{listings_rott.shape}\nDim Hague:{listings_hague.shape}")
# Out:
# Dim AMS: (8945, 75)
# Dim Rott:(1091, 75)
# Dim Hague:(1206, 75)

# %%
# Dataset is 75 cols, I reset the max columns displayed
pd.set_option('display.max_columns', 75)

# %%
listings_ams.head(3,)
# Out:
#        id                          listing_url       scrape_id last_scraped  \
# 0  262394  https://www.airbnb.com/rooms/262394  20240311215737   2024-03-12
# 1  283170  https://www.airbnb.com/rooms/283170  20240311215737   2024-03-12
# 2  286500  https://www.airbnb.com/rooms/286500  20240311215737   2024-03-12
#
#             source                                      name  \
# 0  previous scrape         Charming Studio with Roof Terrace
# 1      city scrape        5-bedrooms house; central location
# 2      city scrape  Centre, canal view with private bathroom
#
#                                          description  \
# 0  Charming Studio  with beautiful Sunny Rooftop ...
# 1  The apartment is a modern five bedroom apartme...
# 2  ((I have a minimum 3 night stay policy. 1 or 2...
#
#                                neighborhood_overview  \
# 0  Close to the old Center of Amsterdam<br />Clos...
# 1                                                NaN
# ...
